# %% [markdown]
# <a href="https://colab.research.google.com/github/nataliakro02/lecture1/blob/regresja/NK_PUM4_regresja_todo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# zaczytanie niezbędnych bibliotek

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# zaczytaj dane dotyczace sprzedazy

# %% [markdown]
# Dwa sposoby

# %%
df = pd.read_csv('Salary Data.csv')

# %%
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "Salary Data.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "rkiattisak/salaly-prediction-for-beginer",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# <ipython-input-3-72cc2aa30810>:9: DeprecationWarning: load_dataset is deprecated and will be removed in future version.
#   df = kagglehub.load_dataset(
# ...
# 100%|██████████| 18.9k/18.9k [00:00<00:00, 14.4MB/s]
# First 5 records:     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %% [markdown]
# preprocessing
#
# 1.   sprawdż typy danych
# 2.   zmien etykiedy na zmienne liczbowe
# 3. w przypadku brakujacych danych uzupelnij (w przypadku etykiet) najczesciej wystepującą wartością lub średnią wartością

# %%
#1

df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
#2

from sklearn.preprocessing import LabelEncoder

# Tworzenie obiektu LabelEncoder
le = LabelEncoder()

# Iteracja przez kolumny DataFrame
for column in df.columns:
  # Sprawdzenie, czy kolumna zawiera dane typu object (tj. tekstowe)
  if df[column].dtype == object:
    # Zamiana etykiet na zmienne liczbowe
    df[column] = le.fit_transform(df[column])

print(df.head())
# Out:
#     Age  Gender  Education Level  Job Title  Years of Experience    Salary
# 0  32.0       1                0        159                  5.0   90000.0
# 1  28.0       0                1         17                  3.0   65000.0
# 2  45.0       1                2        130                 15.0  150000.0
# 3  36.0       0                0        101                  7.0   60000.0
# 4  52.0       1                1         22                 20.0  200000.0

# %%
#3

for column in df.columns:
  if df[column].isnull().any():
    if df[column].dtype == object:
      # W przypadku brakujących danych w kolumnach z etykietami,
      # uzupełnij najczęściej występującą wartością.
      df[column].fillna(df.mode({column})[0], inplace=True)
    else:
      # W przypadku brakujących danych w kolumnach liczbowych,
      # uzupełnij średnią wartością.
      df[column].fillna(df.mean({column}), inplace=True)

print(df.head())
# Out:
#     Age  Gender  Education Level  Job Title  Years of Experience    Salary
# 0  32.0       1                0        159                  5.0   90000.0
# 1  28.0       0                1         17                  3.0   65000.0
# 2  45.0       1                2        130                 15.0  150000.0
# 3  36.0       0                0        101                  7.0   60000.0
# 4  52.0       1                1         22                 20.0  200000.0

# %% [markdown]
# Podziel zbiór danych na testowy i treningowy w stosunku 30/70

# %%
X= df.drop('Salary', axis=1)
y= df['Salary']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=False)

# %%
print(X_train.shape)
# Out:
# (262, 5)

# %% [markdown]
# Stworz model regresji liniowej korzystajac z parametrów domyślnych
# Przykład dokumentacji: https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html#sphx-glr-auto-examples-linear-model-plot-ols-py

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# ocen model na zbiorze testowym za pomocą miar: średni błąd kwadratowy, średni błąd absolutny, wynik wyjaśnionej wariancji

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = regressor.predict(X_test)

print(f"Mean squared error: {mean_squared_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination: {r2_score(y_test, y_pred):.2f}")
# Out:
# Mean squared error: 204522962.96
# Coefficient of determination: 0.91

# %% [markdown]
# spróbuj poprawić model, zacznij od danych, sprawdz korelacje, znormalizuj

# %%
# prompt: spróbuj poprawić model, zacznij od danych, sprawdz korelacje, znormalizuj

# ... (previous code)

# Sprawdzenie korelacji między zmiennymi
correlation_matrix = df.corr()
print("Macierz korelacji:\n", correlation_matrix)

# Normalizacja danych
scaler = StandardScaler()
X_test = X_test.drop("Age", axis = 1)
X_train = X_train.drop("Age", axis = 1)

X_test = scaler.fit_transform(X_test)
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Ponowne stworzenie modelu regresji liniowej z znormalizowanymi danymi
regressor = LinearRegression().fit(X_train, y_train)
y_pred = regressor.predict(X_test)

print(f"Mean squared error (po normalizacji): {mean_squared_error(y_test, y_pred):.2f}")
print(f"Coefficient of determination (po normalizacji): {r2_score(y_test, y_pred):.2f}")

# Możesz również spróbować innych modeli regresji, np. Ridge lub Lasso,
# aby zobaczyć, czy można uzyskać lepsze wyniki.
# Przykład:
# ridge_regressor = Ridge(alpha=1.0).fit(X_train, y_train)
# y_pred_ridge = ridge_regressor.predict(X_test)
# print(f"Mean squared error (Ridge): {mean_squared_error(y_test, y_pred_ridge):.2f}")
# print(f"Coefficient of determination (Ridge): {r2_score(y_test, y_pred_ridge):.2f}")
# Out:
# Macierz korelacji:
#                            Age    Gender  Education Level  Job Title  \
# Age                  1.000000 -0.019865         0.546020   0.116616
# Gender              -0.019865  1.000000         0.008677   0.041562
# Education Level      0.546020  0.008677         1.000000   0.127791
# Job Title            0.116616  0.041562         0.127791   1.000000
# Years of Experience  0.979128  0.002818         0.573355   0.099299
# Salary               0.922335  0.069498         0.650507   0.135033
#
#                      Years of Experience    Salary
# Age                             0.979128  0.922335
# Gender                          0.002818  0.069498
# Education Level                 0.573355  0.650507
# Job Title                       0.099299  0.135033
# Years of Experience             1.000000  0.930338
# Salary                          0.930338  1.000000
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# Zbuduj model regresji odpornej i przetestuj jego predykcje

# %% [markdown]
# Wykreś przewidziane i faktyczne wartości obu modeli (przykład w dokumentacji: https://scikit-learn.org/stable/auto_examples/ensemble/plot_voting_regressor.html#sphx-glr-auto-examples-ensemble-plot-voting-regressor-py)

# %%
# prompt: Zbuduj model regresji odpornej i przetestuj jego predykcje

# ... (previous code)

# Budowa modelu regresji odpornej (np. wykorzystując HuberRegressor)
from sklearn.linear_model import HuberRegressor

huber_regressor = HuberRegressor().fit(X_train, y_train)
y_pred_huber = huber_regressor.predict(X_test)

print(f"Mean squared error (Huber): {mean_squared_error(y_test, y_pred_huber):.2f}")
print(f"Coefficient of determination (Huber): {r2_score(y_test, y_pred_huber):.2f}")


# Wykres przewidzianych i faktycznych wartości dla modelu regresji liniowej
plt.scatter(y_test, y_pred, color='blue', label='Regresja liniowa')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.xlabel('Wartości rzeczywiste')
plt.ylabel('Wartości przewidywane')
plt.title('Regresja liniowa - przewidywane vs. rzeczywiste')
plt.legend()
plt.show()

# Wykres przewidzianych i faktycznych wartości dla modelu regresji odpornej (Huber)
plt.scatter(y_test, y_pred_huber, color='red', label='Regresja odporna (Huber)')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.xlabel('Wartości rzeczywiste')
plt.ylabel('Wartości przewidywane')
plt.title('Regresja odporna (Huber) - przewidywane vs. rzeczywiste')
plt.legend()
plt.show()
# Out:
# Mean squared error (Huber): 212118490.47
# Coefficient of determination (Huber): 0.90

# %% [markdown]
# Zmodyfikuj kod, zeby zwizualizować wynik lepszego z modeli

# %%
if r2_score(y_test, y_pred) > r2_score(y_test, y_pred_huber):
  best_model_y_pred = y_pred
  best_model_name = "Regresja liniowa"
else:
  best_model_y_pred = y_pred_huber
  best_model_name = "Regresja odporna (Huber)"

# Wizualizacja wyniku lepszego modelu
fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
PredictionErrorDisplay.from_predictions(
    y_test,
    y_pred=best_model_y_pred,
    kind="actual_vs_predicted",
    subsample=100,
    ax=axs[0],
    random_state=0,
)
axs[0].set_title("Actual vs. Predicted values")
PredictionErrorDisplay.from_predictions(
    y_test,
    y_pred=best_model_y_pred,
    kind="residual_vs_predicted",
    subsample=100,
    ax=axs[1],
    random_state=0,
)
axs[1].set_title("Residuals vs. Predicted Values")
fig.suptitle(f"Plotting cross-validated predictions for {best_model_name}")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import PredictionErrorDisplay

fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
PredictionErrorDisplay.from_predictions(
    y,
    y_pred=y_pred,
    kind="actual_vs_predicted",
    subsample=100,
    ax=axs[0],
    random_state=0,
)
axs[0].set_title("Actual vs. Predicted values")
PredictionErrorDisplay.from_predictions(
    y,
    y_pred=y_pred,
    kind="residual_vs_predicted",
    subsample=100,
    ax=axs[1],
    random_state=0,
)
axs[1].set_title("Residuals vs. Predicted Values")
fig.suptitle("Plotting cross-validated predictions")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-a8325d8a7ad3> in <cell line: 0>()
#       4
#       5 fig, axs = plt.subplots(ncols=2, figsize=(8, 4))
# ----> 6 PredictionErrorDisplay.from_predictions(
#       7     y,
#       8     y_pred=y_pred,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_plot/regression.py in from_predictions(cls, y_true, y_pred, kind, subsample, random_state, ax, scatter_kwargs, line_kwargs)
#     399             indices = random_state.choice(np.arange(n_samples), size=subsample)
#     400             y_true = _safe_indexing(y_true, indices, axis=0)
# --> 401             y_pred = _safe_indexing(y_pred, indices, axis=0)
#     402
#     403         viz = cls(
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_indexing.py in _safe_indexing(X, indices, axis)
# ...

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(ncols=2, figsize=(10, 5), sharex=True, sharey=True)

ax[0].scatter(X_train, y_train, label="Train data points")
ax[0].plot(
    X_train,
    regressor.predict(X_train),
    linewidth=3,
    color="tab:orange",
    label="Model predictions",
)
ax[0].set(xlabel="Feature", ylabel="Target", title="Train set")
ax[0].legend()

ax[1].scatter(X_test, y_test, label="Test data points")
ax[1].plot(X_test, y_pred, linewidth=3, color="tab:orange", label="Model predictions")
ax[1].set(xlabel="Feature", ylabel="Target", title="Test set")
ax[1].legend()

fig.suptitle("Linear Regression")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-a8f68aa3b3d7> in <cell line: 0>()
#       3 fig, ax = plt.subplots(ncols=2, figsize=(10, 5), sharex=True, sharey=True)
#       4
# ----> 5 ax[0].scatter(X_train, y_train, label="Train data points")
#       6 ax[0].plot(
#       7     X_train,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
# ...
